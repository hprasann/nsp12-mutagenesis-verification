# %% [markdown]
# # NSP12 Mutagenesis – Sanger Sequencing QC
#
# This notebook demonstrates basic QC and validation for NSP12 mutagenesis constructs using Sanger sequencing data.
#
# It:
# - Loads AB1-derived FASTA reads from `data/processed/`
# - Compares them to the corresponding reference FASTA sequences
# - Reports read length, reference length, and percent identity for each sample

# %%
from pathlib import Path
import sys

# Make the project root (.. from notebooks/) importable
PROJECT_ROOT = Path("..").resolve()
if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

from Bio import SeqIO, pairwise2
from src.compare_to_reference import SAMPLES, DATA_DIR, percent_identity

DATA_DIR
# Out:
# PosixPath('data/processed')

# %%
# Look at the first sample pair (read vs reference)
read_name, ref_name = SAMPLES[0]
read_path = DATA_DIR / read_name
ref_path = DATA_DIR / ref_name

print("Read path: ", read_path)
print("Ref  path: ", ref_path)

read_record = next(SeqIO.parse(read_path, "fasta"))
ref_record = next(SeqIO.parse(ref_path, "fasta"))

print("\nRead header: ", read_record.id)
print("Ref header:  ", ref_record.id)
print("Read length:", len(read_record.seq))
print("Ref length: ", len(ref_record.seq))

print("\nFirst 80 bp of read:")
print(str(read_record.seq)[:80])
